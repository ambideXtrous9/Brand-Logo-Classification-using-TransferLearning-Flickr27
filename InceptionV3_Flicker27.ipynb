# %% [markdown]
# <a href="https://colab.research.google.com/github/SUSHOVAN95/Brand-Logo-Detection-using-TransferLearning/blob/main/InceptionV3_Flicker27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import the necessary packages
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications import EfficientNetB7
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam,SGD
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import argparse
import os
import cv2
import tensorflow as tf
import tensorflow_datasets.public_api as tfds

# %%
_URL = 'http://image.ntua.gr/iva/datasets/flickr_logos/flickr_logos_27_dataset.tar.gz'
zip_dir = tf.keras.utils.get_file('/content/logo', origin=_URL, untar=True,extract=True)
# Out:
# Downloading data from http://image.ntua.gr/iva/datasets/flickr_logos/flickr_logos_27_dataset.tar.gz
# 101834752/101827904 [==============================] - 8s 0us/step

# %%
import tarfile

fname = '/content/logo.tar.gz'

if fname.endswith("tar.gz"):
    tar = tarfile.open(fname, "r:gz")
    tar.extractall()
    tar.close()

# %%
fname = '/content/flickr_logos_27_dataset/flickr_logos_27_dataset_images.tar.gz'

if fname.endswith("tar.gz"):
    tar = tarfile.open(fname, "r:gz")
    tar.extractall()
    tar.close()

# %%
src_dir = "flickr_logos_27_dataset_images"
dest = "LOGOS"

if not os.path.exists(dest):
    os.makedirs(dest)

# %%
import pandas as pd
from google.colab.patches import cv2_imshow

# %%
df = pd.read_csv("/content/flickr_logos_27_dataset/flickr_logos_27_dataset_training_set_annotation.txt", sep='\s+',header=None)

# %%
X = df.iloc[:,0]
Y = df.iloc[:,1]

# %%
dtdir = '/content/flickr_logos_27_dataset_images/'

# %%
im = df[0][0]

# %%
size = df.iloc[:,3:]

# %%
img = os.path.join(dtdir,im)

# %%
size = size.values.tolist()

# %%
size[0][0],size[0][1],size[0][2],size[0][3]
# Out:
# (38, 12, 234, 142)

# %%
image = cv2.imread(img)
cv2_imshow(image)
image.shape
# Out:
# <PIL.Image.Image image mode=RGB size=280x210 at 0x7FFA431CFB10>
# (210, 280, 3)

# %%
image = cv2.imread(img)
image = image[size[0][1]:size[0][3],size[0][0]:size[0][2]]
cv2_imshow(image)
image.shape
# Out:
# <PIL.Image.Image image mode=RGB size=196x130 at 0x7FFA424CAE10>
# (130, 196, 3)

# %%
query = pd.read_csv("/content/flickr_logos_27_dataset/flickr_logos_27_dataset_query_set_annotation.txt", sep='\s+',header=None)

# %%
img = os.path.join(dtdir,query[0][5])
image = cv2.imread(img)
cv2_imshow(image)
image.shape
# Out:
# <PIL.Image.Image image mode=RGB size=437x500 at 0x7FFA42455050>
# (500, 437, 3)

# %%
testdist = 'TEST'

# %%
if not os.path.exists(testdist):
    os.makedirs(testdist)

# %%
y = list(set(list(Y)))
y.sort()

# %%
for i in y:
    os.makedirs(os.path.join(testdist,i))

# %%
for i in y:
    os.makedirs(os.path.join(dest,i))

# %%
distractor = pd.read_csv("/content/flickr_logos_27_dataset/flickr_logos_27_dataset_distractor_set_urls.txt", sep='\s+',header=None)
distractor
# Out:
#                                                       0
# 0     http://farm2.static.flickr.com/1184/1013364004...
# 1     http://farm2.static.flickr.com/1108/1047095104...
# 2     http://farm2.static.flickr.com/1359/1076885577...
# 3     http://farm1.static.flickr.com/53/110432189_6d...
# 4     http://farm2.static.flickr.com/1144/1153048029...
# ...                                                 ...
# 4202  http://farm2.static.flickr.com/1254/889763557_...
# 4203  http://farm2.static.flickr.com/1308/901063602_...
# 4204  http://farm1.static.flickr.com/18/93551127_fed...
# 4205  http://farm2.static.flickr.com/1033/978252884_...
# 4206  http://farm2.static.flickr.com/1181/978252894_...
#
# [4207 rows x 1 columns]

# %%
HEIGHT = 224
WIDTH = 224
INIT_LR = 1e-4
EPOCHS =  200
BS = 8

# %%
for i in range(len(X)):
    try:
        destrain = os.path.join(dest,Y[i])
        savepath = os.path.join(destrain,X[i])
        img  = os.path.join(dtdir,X[i])
        image = cv2.imread(img)
        image = image[size[i][1]:size[i][3],size[i][0]:size[i][2]]
        image = cv2.resize(image,(WIDTH,HEIGHT))
        cv2.imwrite(savepath,image)
    except:
        print('error')
        pass
# Out:
# error
# error
# error
# error
# error

# %%
A = query.iloc[:,0]
B = query.iloc[:,1]

# %%
for i in range(len(A)):
    try:
        destrain = os.path.join(testdist,B[i])
        savepath = os.path.join(destrain,A[i])
        img  = os.path.join(dtdir,A[i])
        image = cv2.imread(img)
        image = cv2.resize(image,(WIDTH,HEIGHT))
        cv2.imwrite(savepath,image)
    except:
        print('error')
        pass

# %%
imagePaths = list(paths.list_images(testdist))

# %%
img = imagePaths[63]
print(img)
image = cv2.imread(img)
cv2_imshow(image)
image.shape
# Out:
# TEST/Apple/161270014.jpg
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FFA42473590>
# (224, 224, 3)

# %%
train = ImageDataGenerator(
rescale = 1/255,
horizontal_flip=True,
vertical_flip=True,
shear_range=0.2,
zoom_range=0.2,
featurewise_center=True, # Set input mean to 0 over the dataset, feature-wise
featurewise_std_normalization=True, # Divide inputs by std of the dataset, feature-wise
rotation_range=40, # Degree range for random rotations
width_shift_range=0.2,
height_shift_range=0.2,
fill_mode='nearest')

valid = ImageDataGenerator(
rescale = 1/255,
horizontal_flip=True,
vertical_flip=True,
shear_range=0.2,
zoom_range=0.2,
featurewise_center=True, # Set input mean to 0 over the dataset, feature-wise
featurewise_std_normalization=True, # Divide inputs by std of the dataset, feature-wise
rotation_range=40, # Degree range for random rotations
width_shift_range=0.2,
height_shift_range=0.2,
fill_mode='nearest')

# %%
imagePaths = list(paths.list_images(dest))

# %%
os.makedirs('preview')

# %%
img = load_img(imagePaths[50])  # this is a PIL image
x = img_to_array(img)  # this is a Numpy array with shape (3, 150, 150)
x = x.reshape((1,) + x.shape)  # this is a Numpy array with shape (1, 3, 150, 150)

# the .flow() command below generates batches of randomly transformed images
# and saves the results to the `preview/` directory
i = 0
for batch in train.flow(x, batch_size=1,
                          save_to_dir='preview', save_prefix='yh', save_format='jpeg'):
    i += 1
    if i > 10:
        break  # otherwise the generator would loop indefinitely
# Out:
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:728: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '

# %%
image = cv2.imread(imagePaths[50])
cv2_imshow(image)
image.shape
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FFA4240B710>
# (224, 224, 3)

# %%
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

images = []
for img_path in glob.glob('preview/*.jpeg'):
    images.append(mpimg.imread(img_path))

plt.figure(figsize=(20,10))
columns = 4
for i, image in enumerate(images):
    plt.subplot(len(images) / columns + 1, columns, i + 1)
    plt.imshow(image)

# %%
trainset = train.flow_from_directory(dest,
target_size = (WIDTH,HEIGHT),
batch_size = BS,
shuffle=False,
seed=42,
color_mode='rgb',
class_mode='categorical')
# Out:
# Found 809 images belonging to 27 classes.

# %%
validset = valid.flow_from_directory(testdist,
target_size = (WIDTH,HEIGHT),
batch_size = BS,
shuffle=False,
seed=42,
color_mode='rgb',
class_mode='categorical')
# Out:
# Found 135 images belonging to 27 classes.

# %%
imagePaths = list(paths.list_images(dest))
trainset.filenames
trainset.class_indices
# Out:
# {'Adidas': 0,
#  'Apple': 1,
#  'BMW': 2,
#  'Citroen': 3,
#  'Cocacola': 4,
#  'DHL': 5,
#  'Fedex': 6,
#  'Ferrari': 7,
#  'Ford': 8,
#  'Google': 9,
#  'HP': 10,
#  'Heineken': 11,
#  'Intel': 12,
#  'McDonalds': 13,
#  'Mini': 14,
#  'Nbc': 15,
#  'Nike': 16,
#  'Pepsi': 17,
#  'Porsche': 18,
#  'Puma': 19,
#  'RedBull': 20,
#  'Sprite': 21,
#  'Starbucks': 22,
#  'Texaco': 23,
#  'Unicef': 24,
#  'Vodafone': 25,
#  'Yahoo': 26}

# %%
from tensorflow.keras.applications import InceptionV3

# %%
# load the MobileNetV2 network, ensuring the head FC layer sets are
# left off
baseModel = InceptionV3(weights="imagenet", include_top=False,input_tensor=Input(shape=(WIDTH, HEIGHT, 3)))

# construct the head of the model that will be placed on top of the
# the base model
headModel = baseModel.output
headModel = AveragePooling2D(pool_size=(5,5))(headModel)
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(128, activation="relu")(headModel)
headModel = Dropout(0.4)(headModel)
headModel = Dense(trainset.num_classes, activation="softmax")(headModel)
# place the head FC model on top of the base model (this will become
# the actual model we will train)
model = Model(inputs=baseModel.input, outputs=headModel)
# loop over all layers in the base model and freeze them so they will
# *not* be updated during the first training process
for layer in baseModel.layers:
	layer.trainable = False

# compile our model
print("[INFO] compiling model...")
sgd = SGD(lr=INIT_LR,momentum=0.9,nesterov=False)
model.compile(loss="categorical_crossentropy", optimizer="sgd",
	metrics=["accuracy"])
# train the head of the network
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
# [INFO] compiling model...
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
totalTrain = len(list(paths.list_images(dest)))
totalTrain
# Out:
# 809

# %%
H = model.fit_generator(
	trainset,
  validation_data = validset,
	epochs=EPOCHS)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:728: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# Epoch 1/200
# 102/102 [==============================] - 50s 155ms/step - loss: 3.4359 - accuracy: 0.0593 - val_loss: 3.2503 - val_accuracy: 0.0815
# Epoch 2/200
# 102/102 [==============================] - 13s 129ms/step - loss: 3.1001 - accuracy: 0.1273 - val_loss: 3.0247 - val_accuracy: 0.1926
# Epoch 3/200
# 102/102 [==============================] - 13s 129ms/step - loss: 2.7323 - accuracy: 0.2040 - val_loss: 3.0381 - val_accuracy: 0.1852
# Epoch 4/200
# 102/102 [==============================] - 13s 129ms/step - loss: 2.3948 - accuracy: 0.3028 - val_loss: 2.8061 - val_accuracy: 0.2296
# Epoch 5/200
# 102/102 [==============================] - 13s 128ms/step - loss: 2.0718 - accuracy: 0.3956 - val_loss: 2.4715 - val_accuracy: 0.3481
# Epoch 6/200
# 102/102 [==============================] - 13s 130ms/step - loss: 1.8838 - accuracy: 0.4450 - val_loss: 2.4184 - val_accuracy: 0.3778
# Epoch 7/200
# 102/102 [==============================] - 13s 129ms/step - loss: 1.6642 - accuracy: 0.5278 - val_loss: 2.2823 - val_accuracy: 0.3704
# Epoch 8/200
# 102/102 [==============================] - 13s 129ms/step - loss: 1.4005 - accuracy: 0.5909 - val_loss: 2.5110 - val_accuracy: 0.4000
# Epoch 9/200
# 102/102 [==============================] - 13s 131ms/step - loss: 1.2890 - accuracy: 0.6242 - val_loss: 2.2069 - val_accuracy: 0.4222
# Epoch 10/200
# 102/102 [==============================] - 13s 131ms/step - loss: 1.2244 - accuracy: 0.6452 - val_loss: 2.2821 - val_accuracy: 0.4296
# Epoch 11/200
# 102/102 [==============================] - 13s 131ms/step - loss: 1.1158 - accuracy: 0.6749 - val_loss: 2.1764 - val_accuracy: 0.4000
# Epoch 12/200
# 102/102 [==============================] - 13s 131ms/step - loss: 1.0697 - accuracy: 0.6922 - val_loss: 2.2107 - val_accuracy: 0.4074
# Epoch 13/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.9599 - accuracy: 0.7194 - val_loss: 2.2856 - val_accuracy: 0.4444
# Epoch 14/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.9294 - accuracy: 0.7281 - val_loss: 2.2705 - val_accuracy: 0.4074
# Epoch 15/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.9057 - accuracy: 0.7429 - val_loss: 2.3673 - val_accuracy: 0.4370
# Epoch 16/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.8592 - accuracy: 0.7553 - val_loss: 2.3350 - val_accuracy: 0.4000
# Epoch 17/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.8083 - accuracy: 0.7515 - val_loss: 2.1258 - val_accuracy: 0.4444
# Epoch 18/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.7976 - accuracy: 0.7713 - val_loss: 2.2156 - val_accuracy: 0.4593
# Epoch 19/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.8148 - accuracy: 0.7454 - val_loss: 2.1910 - val_accuracy: 0.4519
# Epoch 20/200
# 102/102 [==============================] - 13s 129ms/step - loss: 0.7803 - accuracy: 0.7577 - val_loss: 2.2425 - val_accuracy: 0.4222
# Epoch 21/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.6811 - accuracy: 0.7948 - val_loss: 2.1929 - val_accuracy: 0.4667
# Epoch 22/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.6907 - accuracy: 0.7998 - val_loss: 2.1243 - val_accuracy: 0.4222
# Epoch 23/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.6381 - accuracy: 0.8133 - val_loss: 2.1199 - val_accuracy: 0.4741
# Epoch 24/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.6561 - accuracy: 0.8059 - val_loss: 2.0929 - val_accuracy: 0.4593
# Epoch 25/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.6420 - accuracy: 0.8096 - val_loss: 2.1983 - val_accuracy: 0.4444
# Epoch 26/200
# 102/102 [==============================] - 13s 132ms/step - loss: 0.5576 - accuracy: 0.8405 - val_loss: 2.1001 - val_accuracy: 0.4593
# Epoch 27/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.6088 - accuracy: 0.8294 - val_loss: 2.1856 - val_accuracy: 0.4444
# Epoch 28/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.5965 - accuracy: 0.8195 - val_loss: 2.1488 - val_accuracy: 0.4444
# Epoch 29/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.5969 - accuracy: 0.8121 - val_loss: 2.0727 - val_accuracy: 0.4741
# Epoch 30/200
# 102/102 [==============================] - 13s 129ms/step - loss: 0.5136 - accuracy: 0.8430 - val_loss: 2.2806 - val_accuracy: 0.4519
# Epoch 31/200
# 102/102 [==============================] - 13s 129ms/step - loss: 0.5069 - accuracy: 0.8504 - val_loss: 2.2117 - val_accuracy: 0.4741
# Epoch 32/200
# 102/102 [==============================] - 13s 129ms/step - loss: 0.4843 - accuracy: 0.8492 - val_loss: 2.2567 - val_accuracy: 0.5037
# Epoch 33/200
# 102/102 [==============================] - 13s 129ms/step - loss: 0.5371 - accuracy: 0.8344 - val_loss: 2.1688 - val_accuracy: 0.4593
# Epoch 34/200
# 102/102 [==============================] - 13s 128ms/step - loss: 0.4534 - accuracy: 0.8603 - val_loss: 2.1862 - val_accuracy: 0.4519
# Epoch 35/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.4631 - accuracy: 0.8492 - val_loss: 2.1323 - val_accuracy: 0.4593
# Epoch 36/200
# 102/102 [==============================] - 13s 129ms/step - loss: 0.5078 - accuracy: 0.8492 - val_loss: 2.2512 - val_accuracy: 0.4889
# Epoch 37/200
# 102/102 [==============================] - 13s 132ms/step - loss: 0.4646 - accuracy: 0.8628 - val_loss: 2.3215 - val_accuracy: 0.4667
# Epoch 38/200
# 102/102 [==============================] - 14s 133ms/step - loss: 0.4767 - accuracy: 0.8554 - val_loss: 2.2046 - val_accuracy: 0.5185
# Epoch 39/200
# 102/102 [==============================] - 14s 134ms/step - loss: 0.4705 - accuracy: 0.8603 - val_loss: 2.2086 - val_accuracy: 0.5037
# Epoch 40/200
# 102/102 [==============================] - 14s 135ms/step - loss: 0.4145 - accuracy: 0.8752 - val_loss: 2.2335 - val_accuracy: 0.4815
# Epoch 41/200
# 102/102 [==============================] - 14s 132ms/step - loss: 0.4673 - accuracy: 0.8529 - val_loss: 2.0928 - val_accuracy: 0.5185
# Epoch 42/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.3983 - accuracy: 0.8925 - val_loss: 2.1681 - val_accuracy: 0.4593
# Epoch 43/200
# 102/102 [==============================] - 13s 132ms/step - loss: 0.4205 - accuracy: 0.8702 - val_loss: 2.3682 - val_accuracy: 0.4667
# Epoch 44/200
# 102/102 [==============================] - 13s 132ms/step - loss: 0.3890 - accuracy: 0.8888 - val_loss: 2.1956 - val_accuracy: 0.4889
# Epoch 45/200
# 102/102 [==============================] - 14s 132ms/step - loss: 0.3997 - accuracy: 0.8739 - val_loss: 2.0882 - val_accuracy: 0.5481
# Epoch 46/200
# 102/102 [==============================] - 13s 132ms/step - loss: 0.3764 - accuracy: 0.8789 - val_loss: 2.2170 - val_accuracy: 0.4593
# Epoch 47/200
# 102/102 [==============================] - 13s 132ms/step - loss: 0.4129 - accuracy: 0.8714 - val_loss: 2.1140 - val_accuracy: 0.4519
# Epoch 48/200
# 102/102 [==============================] - 13s 132ms/step - loss: 0.3546 - accuracy: 0.8925 - val_loss: 2.0982 - val_accuracy: 0.5037
# Epoch 49/200
# 102/102 [==============================] - 14s 132ms/step - loss: 0.3618 - accuracy: 0.8962 - val_loss: 2.3042 - val_accuracy: 0.5185
# Epoch 50/200
# 102/102 [==============================] - 14s 133ms/step - loss: 0.3273 - accuracy: 0.9048 - val_loss: 2.2277 - val_accuracy: 0.4593
# Epoch 51/200
# 102/102 [==============================] - 14s 133ms/step - loss: 0.3783 - accuracy: 0.8888 - val_loss: 2.2650 - val_accuracy: 0.5111
# Epoch 52/200
# 102/102 [==============================] - 14s 133ms/step - loss: 0.3612 - accuracy: 0.8974 - val_loss: 2.0539 - val_accuracy: 0.4667
# Epoch 53/200
# 102/102 [==============================] - 14s 133ms/step - loss: 0.3458 - accuracy: 0.8986 - val_loss: 2.2086 - val_accuracy: 0.4667
# Epoch 54/200
# 102/102 [==============================] - 14s 133ms/step - loss: 0.4027 - accuracy: 0.8739 - val_loss: 2.2052 - val_accuracy: 0.4889
# Epoch 55/200
# 102/102 [==============================] - 14s 133ms/step - loss: 0.3643 - accuracy: 0.8863 - val_loss: 2.3298 - val_accuracy: 0.4741
# Epoch 56/200
# 102/102 [==============================] - 14s 132ms/step - loss: 0.3162 - accuracy: 0.9085 - val_loss: 2.3817 - val_accuracy: 0.4963
# Epoch 57/200
# 102/102 [==============================] - 14s 133ms/step - loss: 0.3440 - accuracy: 0.8912 - val_loss: 2.2192 - val_accuracy: 0.4593
# Epoch 58/200
# 102/102 [==============================] - 13s 132ms/step - loss: 0.2920 - accuracy: 0.9184 - val_loss: 2.3649 - val_accuracy: 0.5185
# Epoch 59/200
# 102/102 [==============================] - 14s 133ms/step - loss: 0.3305 - accuracy: 0.9110 - val_loss: 2.3968 - val_accuracy: 0.4889
# Epoch 60/200
# 102/102 [==============================] - 14s 134ms/step - loss: 0.3033 - accuracy: 0.9184 - val_loss: 2.2272 - val_accuracy: 0.4815
# Epoch 61/200
# 102/102 [==============================] - 14s 133ms/step - loss: 0.2973 - accuracy: 0.9147 - val_loss: 2.4171 - val_accuracy: 0.4519
# Epoch 62/200
# 102/102 [==============================] - 14s 133ms/step - loss: 0.3294 - accuracy: 0.8962 - val_loss: 2.3648 - val_accuracy: 0.4815
# Epoch 63/200
# 102/102 [==============================] - 14s 134ms/step - loss: 0.3512 - accuracy: 0.8999 - val_loss: 2.1789 - val_accuracy: 0.5481
# Epoch 64/200
# 102/102 [==============================] - 14s 132ms/step - loss: 0.3686 - accuracy: 0.8826 - val_loss: 2.1740 - val_accuracy: 0.5333
# Epoch 65/200
# 102/102 [==============================] - 14s 134ms/step - loss: 0.2794 - accuracy: 0.9122 - val_loss: 2.2179 - val_accuracy: 0.5185
# Epoch 66/200
# 102/102 [==============================] - 14s 136ms/step - loss: 0.3147 - accuracy: 0.8986 - val_loss: 2.2963 - val_accuracy: 0.5037
# Epoch 67/200
# 102/102 [==============================] - 14s 134ms/step - loss: 0.3028 - accuracy: 0.8999 - val_loss: 2.1565 - val_accuracy: 0.5407
# Epoch 68/200
# 102/102 [==============================] - 14s 134ms/step - loss: 0.2665 - accuracy: 0.9209 - val_loss: 2.3560 - val_accuracy: 0.4889
# Epoch 69/200
# 102/102 [==============================] - 14s 134ms/step - loss: 0.3166 - accuracy: 0.8986 - val_loss: 2.2681 - val_accuracy: 0.5037
# Epoch 70/200
# 102/102 [==============================] - 14s 133ms/step - loss: 0.3042 - accuracy: 0.9098 - val_loss: 2.2266 - val_accuracy: 0.5185
# Epoch 71/200
# 102/102 [==============================] - 14s 134ms/step - loss: 0.2943 - accuracy: 0.9061 - val_loss: 2.2697 - val_accuracy: 0.4815
# Epoch 72/200
# 102/102 [==============================] - 14s 134ms/step - loss: 0.2914 - accuracy: 0.9122 - val_loss: 2.2128 - val_accuracy: 0.4889
# Epoch 73/200
# 102/102 [==============================] - 14s 133ms/step - loss: 0.2641 - accuracy: 0.9197 - val_loss: 2.2644 - val_accuracy: 0.4667
# Epoch 74/200
# 102/102 [==============================] - 14s 133ms/step - loss: 0.2693 - accuracy: 0.9271 - val_loss: 2.3194 - val_accuracy: 0.5111
# Epoch 75/200
# 102/102 [==============================] - 14s 133ms/step - loss: 0.2978 - accuracy: 0.9135 - val_loss: 2.4026 - val_accuracy: 0.4741
# Epoch 76/200
# 102/102 [==============================] - 14s 134ms/step - loss: 0.2549 - accuracy: 0.9258 - val_loss: 2.2445 - val_accuracy: 0.4815
# Epoch 77/200
# 102/102 [==============================] - 14s 134ms/step - loss: 0.2853 - accuracy: 0.9159 - val_loss: 2.4136 - val_accuracy: 0.5037
# Epoch 78/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.2334 - accuracy: 0.9320 - val_loss: 2.3702 - val_accuracy: 0.4667
# Epoch 79/200
# 102/102 [==============================] - 14s 133ms/step - loss: 0.2537 - accuracy: 0.9295 - val_loss: 2.1882 - val_accuracy: 0.5111
# Epoch 80/200
# 102/102 [==============================] - 13s 132ms/step - loss: 0.2497 - accuracy: 0.9234 - val_loss: 2.3955 - val_accuracy: 0.4963
# Epoch 81/200
# 102/102 [==============================] - 14s 133ms/step - loss: 0.2503 - accuracy: 0.9209 - val_loss: 2.0778 - val_accuracy: 0.5185
# Epoch 82/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.2845 - accuracy: 0.9209 - val_loss: 2.4414 - val_accuracy: 0.4815
# Epoch 83/200
# 102/102 [==============================] - 13s 132ms/step - loss: 0.2473 - accuracy: 0.9184 - val_loss: 2.4728 - val_accuracy: 0.4741
# Epoch 84/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.2645 - accuracy: 0.9271 - val_loss: 2.4045 - val_accuracy: 0.4963
# Epoch 85/200
# 102/102 [==============================] - 14s 132ms/step - loss: 0.2515 - accuracy: 0.9246 - val_loss: 2.2936 - val_accuracy: 0.4889
# Epoch 86/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.2581 - accuracy: 0.9271 - val_loss: 2.5029 - val_accuracy: 0.4519
# Epoch 87/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.2189 - accuracy: 0.9468 - val_loss: 2.5740 - val_accuracy: 0.4741
# Epoch 88/200
# 102/102 [==============================] - 13s 132ms/step - loss: 0.2429 - accuracy: 0.9345 - val_loss: 2.4532 - val_accuracy: 0.5037
# Epoch 89/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.2513 - accuracy: 0.9197 - val_loss: 2.2040 - val_accuracy: 0.4667
# Epoch 90/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.3006 - accuracy: 0.9036 - val_loss: 2.3575 - val_accuracy: 0.4889
# Epoch 91/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.2321 - accuracy: 0.9308 - val_loss: 2.3390 - val_accuracy: 0.5037
# Epoch 92/200
# 102/102 [==============================] - 14s 132ms/step - loss: 0.2235 - accuracy: 0.9320 - val_loss: 2.3271 - val_accuracy: 0.4963
# Epoch 93/200
# 102/102 [==============================] - 14s 133ms/step - loss: 0.2477 - accuracy: 0.9370 - val_loss: 2.4151 - val_accuracy: 0.5185
# Epoch 94/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.1894 - accuracy: 0.9530 - val_loss: 2.3354 - val_accuracy: 0.5185
# Epoch 95/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.2791 - accuracy: 0.9110 - val_loss: 2.5797 - val_accuracy: 0.4889
# Epoch 96/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.2361 - accuracy: 0.9357 - val_loss: 2.4668 - val_accuracy: 0.5111
# Epoch 97/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.2276 - accuracy: 0.9308 - val_loss: 2.3687 - val_accuracy: 0.5037
# Epoch 98/200
# 102/102 [==============================] - 13s 132ms/step - loss: 0.2350 - accuracy: 0.9308 - val_loss: 2.4968 - val_accuracy: 0.4741
# Epoch 99/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.1821 - accuracy: 0.9506 - val_loss: 2.5597 - val_accuracy: 0.4741
# Epoch 100/200
# 102/102 [==============================] - 13s 129ms/step - loss: 0.1991 - accuracy: 0.9407 - val_loss: 2.3890 - val_accuracy: 0.4815
# Epoch 101/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.2151 - accuracy: 0.9382 - val_loss: 2.3399 - val_accuracy: 0.4963
# Epoch 102/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.2380 - accuracy: 0.9258 - val_loss: 2.6240 - val_accuracy: 0.4148
# Epoch 103/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.1915 - accuracy: 0.9530 - val_loss: 2.5034 - val_accuracy: 0.5037
# Epoch 104/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.2028 - accuracy: 0.9407 - val_loss: 2.4037 - val_accuracy: 0.4889
# Epoch 105/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.2222 - accuracy: 0.9308 - val_loss: 2.2489 - val_accuracy: 0.5407
# Epoch 106/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.1735 - accuracy: 0.9468 - val_loss: 2.5199 - val_accuracy: 0.4815
# Epoch 107/200
# 102/102 [==============================] - 13s 129ms/step - loss: 0.1868 - accuracy: 0.9407 - val_loss: 2.5806 - val_accuracy: 0.4741
# Epoch 108/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.2049 - accuracy: 0.9333 - val_loss: 2.5515 - val_accuracy: 0.5037
# Epoch 109/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.2071 - accuracy: 0.9333 - val_loss: 2.6453 - val_accuracy: 0.4889
# Epoch 110/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.1957 - accuracy: 0.9357 - val_loss: 2.5070 - val_accuracy: 0.4889
# Epoch 111/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.1965 - accuracy: 0.9468 - val_loss: 2.5726 - val_accuracy: 0.4815
# Epoch 112/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.2262 - accuracy: 0.9246 - val_loss: 2.5610 - val_accuracy: 0.4667
# Epoch 113/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.2219 - accuracy: 0.9345 - val_loss: 2.4658 - val_accuracy: 0.5185
# Epoch 114/200
# 102/102 [==============================] - 13s 129ms/step - loss: 0.1812 - accuracy: 0.9444 - val_loss: 2.3476 - val_accuracy: 0.4815
# Epoch 115/200
# 102/102 [==============================] - 14s 132ms/step - loss: 0.1966 - accuracy: 0.9468 - val_loss: 2.2126 - val_accuracy: 0.5111
# Epoch 116/200
# 102/102 [==============================] - 14s 133ms/step - loss: 0.1804 - accuracy: 0.9419 - val_loss: 2.4020 - val_accuracy: 0.5111
# Epoch 117/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.1873 - accuracy: 0.9456 - val_loss: 2.4939 - val_accuracy: 0.4444
# Epoch 118/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.1685 - accuracy: 0.9567 - val_loss: 2.6550 - val_accuracy: 0.4519
# Epoch 119/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.1692 - accuracy: 0.9444 - val_loss: 2.6361 - val_accuracy: 0.4889
# Epoch 120/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.1982 - accuracy: 0.9394 - val_loss: 2.3517 - val_accuracy: 0.4815
# Epoch 121/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.1675 - accuracy: 0.9481 - val_loss: 2.5292 - val_accuracy: 0.4741
# Epoch 122/200
# 102/102 [==============================] - 13s 129ms/step - loss: 0.1744 - accuracy: 0.9431 - val_loss: 2.7311 - val_accuracy: 0.5037
# Epoch 123/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.2142 - accuracy: 0.9382 - val_loss: 2.6969 - val_accuracy: 0.4815
# Epoch 124/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.1988 - accuracy: 0.9419 - val_loss: 2.4295 - val_accuracy: 0.5037
# Epoch 125/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.1658 - accuracy: 0.9493 - val_loss: 2.5556 - val_accuracy: 0.4667
# Epoch 126/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.2103 - accuracy: 0.9382 - val_loss: 2.6286 - val_accuracy: 0.4889
# Epoch 127/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.1800 - accuracy: 0.9407 - val_loss: 2.4635 - val_accuracy: 0.4815
# Epoch 128/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.1763 - accuracy: 0.9530 - val_loss: 2.3781 - val_accuracy: 0.5333
# Epoch 129/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.1387 - accuracy: 0.9567 - val_loss: 2.6418 - val_accuracy: 0.4741
# Epoch 130/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.1345 - accuracy: 0.9642 - val_loss: 2.6250 - val_accuracy: 0.5556
# Epoch 131/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.1576 - accuracy: 0.9543 - val_loss: 2.6280 - val_accuracy: 0.4963
# Epoch 132/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.1651 - accuracy: 0.9468 - val_loss: 2.6637 - val_accuracy: 0.5111
# Epoch 133/200
# 102/102 [==============================] - 13s 129ms/step - loss: 0.2143 - accuracy: 0.9370 - val_loss: 2.5300 - val_accuracy: 0.5037
# Epoch 134/200
# 102/102 [==============================] - 13s 129ms/step - loss: 0.1368 - accuracy: 0.9654 - val_loss: 2.6801 - val_accuracy: 0.5037
# Epoch 135/200
# 102/102 [==============================] - 13s 128ms/step - loss: 0.1607 - accuracy: 0.9493 - val_loss: 2.4137 - val_accuracy: 0.5111
# Epoch 136/200
# 102/102 [==============================] - 14s 136ms/step - loss: 0.1997 - accuracy: 0.9444 - val_loss: 2.6339 - val_accuracy: 0.5037
# Epoch 137/200
# 102/102 [==============================] - 13s 129ms/step - loss: 0.1895 - accuracy: 0.9468 - val_loss: 2.3195 - val_accuracy: 0.5185
# Epoch 138/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.1632 - accuracy: 0.9543 - val_loss: 2.8062 - val_accuracy: 0.4667
# Epoch 139/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.1760 - accuracy: 0.9481 - val_loss: 2.4707 - val_accuracy: 0.5037
# Epoch 140/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.1901 - accuracy: 0.9394 - val_loss: 2.4121 - val_accuracy: 0.4667
# Epoch 141/200
# 102/102 [==============================] - 13s 132ms/step - loss: 0.1669 - accuracy: 0.9543 - val_loss: 2.3191 - val_accuracy: 0.5037
# Epoch 142/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.1662 - accuracy: 0.9407 - val_loss: 2.4456 - val_accuracy: 0.5407
# Epoch 143/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.1642 - accuracy: 0.9530 - val_loss: 2.6323 - val_accuracy: 0.5407
# Epoch 144/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.1929 - accuracy: 0.9431 - val_loss: 2.5432 - val_accuracy: 0.5259
# Epoch 145/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.1716 - accuracy: 0.9493 - val_loss: 2.5872 - val_accuracy: 0.5185
# Epoch 146/200
# 102/102 [==============================] - 13s 128ms/step - loss: 0.1851 - accuracy: 0.9481 - val_loss: 2.5894 - val_accuracy: 0.5111
# Epoch 147/200
# 102/102 [==============================] - 13s 128ms/step - loss: 0.1699 - accuracy: 0.9518 - val_loss: 2.6077 - val_accuracy: 0.4889
# Epoch 148/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.1903 - accuracy: 0.9419 - val_loss: 2.6114 - val_accuracy: 0.4963
# Epoch 149/200
# 102/102 [==============================] - 13s 128ms/step - loss: 0.1774 - accuracy: 0.9468 - val_loss: 2.4706 - val_accuracy: 0.4889
# Epoch 150/200
# 102/102 [==============================] - 13s 128ms/step - loss: 0.1738 - accuracy: 0.9481 - val_loss: 2.4078 - val_accuracy: 0.5333
# Epoch 151/200
# 102/102 [==============================] - 13s 129ms/step - loss: 0.1691 - accuracy: 0.9468 - val_loss: 2.7318 - val_accuracy: 0.4815
# Epoch 152/200
# 102/102 [==============================] - 13s 129ms/step - loss: 0.1430 - accuracy: 0.9654 - val_loss: 2.7109 - val_accuracy: 0.4815
# Epoch 153/200
# 102/102 [==============================] - 13s 128ms/step - loss: 0.1689 - accuracy: 0.9518 - val_loss: 2.4382 - val_accuracy: 0.4741
# Epoch 154/200
# 102/102 [==============================] - 13s 127ms/step - loss: 0.1592 - accuracy: 0.9419 - val_loss: 2.7521 - val_accuracy: 0.4593
# Epoch 155/200
# 102/102 [==============================] - 13s 129ms/step - loss: 0.1319 - accuracy: 0.9629 - val_loss: 2.6828 - val_accuracy: 0.5037
# Epoch 156/200
# 102/102 [==============================] - 13s 128ms/step - loss: 0.1261 - accuracy: 0.9604 - val_loss: 2.4271 - val_accuracy: 0.5333
# Epoch 157/200
# 102/102 [==============================] - 13s 128ms/step - loss: 0.1606 - accuracy: 0.9493 - val_loss: 2.5574 - val_accuracy: 0.5185
# Epoch 158/200
# 102/102 [==============================] - 13s 129ms/step - loss: 0.1352 - accuracy: 0.9629 - val_loss: 2.7421 - val_accuracy: 0.4815
# Epoch 159/200
# 102/102 [==============================] - 13s 129ms/step - loss: 0.1674 - accuracy: 0.9481 - val_loss: 2.6009 - val_accuracy: 0.5037
# Epoch 160/200
# 102/102 [==============================] - 13s 129ms/step - loss: 0.1623 - accuracy: 0.9481 - val_loss: 2.5797 - val_accuracy: 0.5111
# Epoch 161/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.1617 - accuracy: 0.9530 - val_loss: 2.8030 - val_accuracy: 0.5111
# Epoch 162/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.1616 - accuracy: 0.9481 - val_loss: 2.6517 - val_accuracy: 0.5185
# Epoch 163/200
# 102/102 [==============================] - 13s 128ms/step - loss: 0.1368 - accuracy: 0.9604 - val_loss: 2.3781 - val_accuracy: 0.4815
# Epoch 164/200
# 102/102 [==============================] - 13s 128ms/step - loss: 0.1651 - accuracy: 0.9506 - val_loss: 2.5378 - val_accuracy: 0.5333
# Epoch 165/200
# 102/102 [==============================] - 13s 129ms/step - loss: 0.1647 - accuracy: 0.9543 - val_loss: 2.5866 - val_accuracy: 0.4889
# Epoch 166/200
# 102/102 [==============================] - 13s 128ms/step - loss: 0.1485 - accuracy: 0.9530 - val_loss: 2.6809 - val_accuracy: 0.5037
# Epoch 167/200
# 102/102 [==============================] - 13s 128ms/step - loss: 0.1425 - accuracy: 0.9444 - val_loss: 2.5705 - val_accuracy: 0.4963
# Epoch 168/200
# 102/102 [==============================] - 13s 129ms/step - loss: 0.1524 - accuracy: 0.9543 - val_loss: 2.7314 - val_accuracy: 0.4963
# Epoch 169/200
# 102/102 [==============================] - 13s 128ms/step - loss: 0.1355 - accuracy: 0.9604 - val_loss: 2.3343 - val_accuracy: 0.5111
# Epoch 170/200
# 102/102 [==============================] - 13s 128ms/step - loss: 0.1450 - accuracy: 0.9555 - val_loss: 2.4912 - val_accuracy: 0.5481
# Epoch 171/200
# 102/102 [==============================] - 13s 129ms/step - loss: 0.1340 - accuracy: 0.9629 - val_loss: 2.6830 - val_accuracy: 0.5111
# Epoch 172/200
# 102/102 [==============================] - 13s 128ms/step - loss: 0.1292 - accuracy: 0.9592 - val_loss: 2.6819 - val_accuracy: 0.4963
# Epoch 173/200
# 102/102 [==============================] - 13s 129ms/step - loss: 0.1323 - accuracy: 0.9654 - val_loss: 2.7675 - val_accuracy: 0.5037
# Epoch 174/200
# 102/102 [==============================] - 13s 129ms/step - loss: 0.1501 - accuracy: 0.9530 - val_loss: 2.5890 - val_accuracy: 0.5037
# Epoch 175/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.1089 - accuracy: 0.9691 - val_loss: 2.7251 - val_accuracy: 0.4741
# Epoch 176/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.1363 - accuracy: 0.9654 - val_loss: 2.7437 - val_accuracy: 0.4667
# Epoch 177/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.1573 - accuracy: 0.9543 - val_loss: 2.4932 - val_accuracy: 0.5037
# Epoch 178/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.1597 - accuracy: 0.9530 - val_loss: 2.5572 - val_accuracy: 0.4741
# Epoch 179/200
# 102/102 [==============================] - 13s 132ms/step - loss: 0.1178 - accuracy: 0.9654 - val_loss: 2.5895 - val_accuracy: 0.5259
# Epoch 180/200
# 102/102 [==============================] - 14s 133ms/step - loss: 0.1041 - accuracy: 0.9740 - val_loss: 2.5455 - val_accuracy: 0.4889
# Epoch 181/200
# 102/102 [==============================] - 14s 133ms/step - loss: 0.1338 - accuracy: 0.9567 - val_loss: 2.6633 - val_accuracy: 0.4815
# Epoch 182/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.1394 - accuracy: 0.9555 - val_loss: 2.7590 - val_accuracy: 0.4741
# Epoch 183/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.1471 - accuracy: 0.9604 - val_loss: 2.7555 - val_accuracy: 0.4889
# Epoch 184/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.1185 - accuracy: 0.9604 - val_loss: 2.4613 - val_accuracy: 0.5556
# Epoch 185/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.1482 - accuracy: 0.9493 - val_loss: 2.5666 - val_accuracy: 0.5037
# Epoch 186/200
# 102/102 [==============================] - 13s 132ms/step - loss: 0.1421 - accuracy: 0.9604 - val_loss: 2.5075 - val_accuracy: 0.5037
# Epoch 187/200
# 102/102 [==============================] - 13s 133ms/step - loss: 0.1368 - accuracy: 0.9592 - val_loss: 2.3283 - val_accuracy: 0.5037
# Epoch 188/200
# 102/102 [==============================] - 13s 132ms/step - loss: 0.1079 - accuracy: 0.9716 - val_loss: 2.6271 - val_accuracy: 0.5333
# Epoch 189/200
# 102/102 [==============================] - 13s 132ms/step - loss: 0.1366 - accuracy: 0.9567 - val_loss: 2.4060 - val_accuracy: 0.5111
# Epoch 190/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.1525 - accuracy: 0.9481 - val_loss: 2.6212 - val_accuracy: 0.5407
# Epoch 191/200
# 102/102 [==============================] - 13s 128ms/step - loss: 0.1352 - accuracy: 0.9604 - val_loss: 2.4237 - val_accuracy: 0.5111
# Epoch 192/200
# 102/102 [==============================] - 13s 129ms/step - loss: 0.1434 - accuracy: 0.9629 - val_loss: 2.8284 - val_accuracy: 0.4815
# Epoch 193/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.1224 - accuracy: 0.9604 - val_loss: 2.1620 - val_accuracy: 0.5630
# Epoch 194/200
# 102/102 [==============================] - 13s 130ms/step - loss: 0.1168 - accuracy: 0.9666 - val_loss: 2.7674 - val_accuracy: 0.4963
# Epoch 195/200
# 102/102 [==============================] - 13s 132ms/step - loss: 0.1268 - accuracy: 0.9629 - val_loss: 2.5788 - val_accuracy: 0.4889
# Epoch 196/200
# 102/102 [==============================] - 13s 132ms/step - loss: 0.1102 - accuracy: 0.9703 - val_loss: 2.7423 - val_accuracy: 0.5333
# Epoch 197/200
# 102/102 [==============================] - 14s 132ms/step - loss: 0.1379 - accuracy: 0.9580 - val_loss: 2.5723 - val_accuracy: 0.5333
# Epoch 198/200
# 102/102 [==============================] - 14s 135ms/step - loss: 0.1149 - accuracy: 0.9679 - val_loss: 2.7099 - val_accuracy: 0.4815
# Epoch 199/200
# 102/102 [==============================] - 14s 134ms/step - loss: 0.0913 - accuracy: 0.9703 - val_loss: 2.8404 - val_accuracy: 0.4889
# Epoch 200/200
# 102/102 [==============================] - 13s 131ms/step - loss: 0.1284 - accuracy: 0.9654 - val_loss: 2.6611 - val_accuracy: 0.5037

# %%
# plot the training loss and accuracy
N = EPOCHS
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.title("Training Loss and Val Loss")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.show()
plt.savefig('graph.png')

# %%
N = EPOCHS
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title(" Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Accuracy")
plt.legend(loc="lower left")
plt.show()

# %%
# reset the testing generator and then use our trained model to
# make predictions on the data
print("[INFO] evaluating after fine-tuning network...")
validset.reset()
predIdxs = model.predict(x=validset)
predIdxs = np.argmax(predIdxs, axis=1)
print(classification_report(validset.classes, predIdxs,
	target_names=validset.class_indices.keys()))
# serialize the model to disk
print("[INFO] serializing network...")
model.save('logo.model', save_format="h5")
# Out:
# [INFO] evaluating after fine-tuning network...
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:728: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#       Adidas       0.00      0.00      0.00         5
#        Apple       0.71      1.00      0.83         5
#          BMW       0.50      0.40      0.44         5
#      Citroen       0.30      0.60      0.40         5
#     Cocacola       0.00      0.00      0.00         5
#          DHL       0.75      0.60      0.67         5
#        Fedex       0.60      0.60      0.60         5
#      Ferrari       0.38      0.60      0.46         5
#         Ford       0.75      0.60      0.67         5
#       Google       0.40      0.80      0.53         5
#           HP       0.75      0.60      0.67         5
#     Heineken       0.33      0.60      0.43         5
#        Intel       0.40      0.40      0.40         5
#    McDonalds       0.25      0.20      0.22         5
#         Mini       0.75      0.60      0.67         5
#          Nbc       1.00      0.40      0.57         5
#         Nike       0.50      0.60      0.55         5
#        Pepsi       0.25      0.20      0.22         5
#      Porsche       0.83      1.00      0.91         5
#         Puma       0.50      0.20      0.29         5
#      RedBull       0.38      0.60      0.46         5
#       Sprite       0.57      0.80      0.67         5
#    Starbucks       0.83      1.00      0.91         5
#       Texaco       0.00      0.00      0.00         5
#       Unicef       0.33      0.20      0.25         5
#     Vodafone       0.67      0.40      0.50         5
#        Yahoo       0.50      0.80      0.62         5
#
#     accuracy                           0.51       135
#    macro avg       0.49      0.51      0.48       135
# weighted avg       0.49      0.51      0.48       135
#
# [INFO] serializing network...
